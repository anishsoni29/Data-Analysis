# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/anishsoni/Desktop/Job_Oppurtunity/job.csv')

# %%
data.head()
# Out:
#                           job_title  \
# 0    Business Development Associate
# 1  IELTS/PTE/Spoken English Trainer
# 2                  Fashion Designer
# 3         Corporate Sales Executive
# 4           Junior Python Developer
#
#                                 company_name   location          start_date  \
# 0                             Break The Code     Mumbai  Starts Immediately
# 1               DePioneer Education Overseas      Delhi  Starts Immediately
# 2                           Valkyre Clothing     Mumbai  Starts Immediately
# 3  Kompass India Information Private Limited     Mumbai  Starts Immediately
# 4     Extension Technologies Private Limited  Faridabad  Starts Immediately
#
#                      ctc experience                                 posted
# 0  ₹ 2,00,000 - 3,00,000  0-1 years                             3 days ago
# 1  ₹ 3,00,000 - 3,50,000  0-2 years                             1 week ago
# 2  ₹ 3,00,000 - 3,50,000  0-2 years  3 days ago\n\n\nBe an early applicant
# 3  ₹ 2,00,000 - 4,00,000  0-5 years                            3 weeks ago
# 4  ₹ 2,40,000 - 3,60,000  0-2 years                            2 weeks ago

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4596 entries, 0 to 4595
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_title     4596 non-null   object
#  1   company_name  4596 non-null   object
#  2   location      4596 non-null   object
#  3   start_date    4596 non-null   object
#  4   ctc           4596 non-null   object
#  5   experience    4596 non-null   object
#  6   posted        4596 non-null   object
# dtypes: object(7)
# memory usage: 251.5+ KB

# %%
data['posted'].value_counts()
# Out:
# 3 weeks ago                                 1326
# 1 week ago                                  1031
# 2 weeks ago                                  936
# 3 days ago                                   198
# 2 days ago                                   138
# 4 days ago                                   109
# 6 days ago                                   100
# 5 days ago                                    98
# 1 week ago\n\n\nBe an early applicant         84
# 3 weeks ago\n\n\nBe an early applicant        81
# 2 weeks ago\n\n\nBe an early applicant        78
# 1 day ago                                     74
# Few hours ago                                 60
# 2 days ago\n\n\nBe an early applicant         49
# 3 days ago\n\n\nBe an early applicant         46
# 1 day ago\n\n\nBe an early applicant          29
# 4 days ago\n\n\nBe an early applicant         26
# Just now\n\n\nBe an early applicant           26
# Few hours ago\n\n\nBe an early applicant      23
# Today                                         19
# Today\n\n\nBe an early applicant              18
# 7 days ago                                    14
# 5 days ago\n\n\nBe an early applicant         13
# Just now                                      10
# 7 days ago\n\n\nBe an early applicant          6
# 6 days ago\n\n\nBe an early applicant          4
# Name: posted, dtype: int64

# %% [markdown]
# ## Cleaning the data

# %%
data['posted'] = data['posted'].str.replace("\n\n\nBe an early applicant", " ")
data['min_ctc'] = data['ctc'].str.split("-").str[0].str.strip().str.replace("₹", "").str.replace(",", "")
data["max_ctc"] = data["ctc"].str.split("-").str[-1].str.strip().str.replace("₹", "").str.replace(",", "")
data[["min_ctc", "max_ctc"]] = data[["min_ctc", "max_ctc"]].apply(pd.to_numeric, errors='coerce')

# %%
data.sample(5)
# Out:
#                       job_title                                company_name  \
# 2142          iOS App Developer  Buddha Education Association Incorporation
# 2934         Presales Executive       Birdvision Consulting Private Limited
# 853   Junior Operations Manager                                   Documitra
# 1196                UI Designer                               Future Skills
# 2583       Data Entry Executive                                  A1 Advance
#
#                                                location          start_date  \
# 2142                                     Work from home  Starts Immediately
# 2934                                               Pune  Starts Immediately
# 853                                               Ajmer  Starts Immediately
# 1196                                          Hyderabad  Starts Immediately
# 2583  Chennai, Coimbatore, Madurai, Puducherry, Siva...  Starts Immediately
#
#                         ctc experience       posted   min_ctc   max_ctc
# 2142             ₹ 5,00,000  0-5 years   1 week ago  500000.0  500000.0
# 2934  ₹ 2,00,000 - 2,60,000  0-2 years  2 weeks ago  200000.0  260000.0
# 853   ₹ 2,00,000 - 2,50,000  0-2 years  3 days ago   200000.0  250000.0
# 1196  ₹ 3,00,000 - 5,00,000  0-5 years   1 week ago  300000.0  500000.0
# 2583  ₹ 3,00,000 - 6,00,000  0-5 years  2 weeks ago  300000.0  600000.0

# %%
data['experience'] = data['experience'].str.replace('years','')
data['min_experience'] = data['experience'].str.split('-').str[0].str.strip()
data['max_experience'] = data['experience'].str.split('-').str[-1].str.strip()
data[["min_experience", "max_experience"]] = data[["min_experience", "max_experience"]].apply(pd.to_numeric, errors='coerce')

# %%
data.sample(5)
# Out:
#                          job_title  \
# 3804  Business Development Manager
# 4218         Field Sales Executive
# 260           Social Media Manager
# 728               Career Counselor
# 2237             Finance Executive
#
#                                            company_name  \
# 3804                             Haiden (Mumbai, India)
# 4218                               Piegon Media Pvt Ltd
# 260                                  Error Technologies
# 728   DGguru Learning Solutions Private Limited (Men...
# 2237                                         A1 Advance
#
#                                                location          start_date  \
# 3804  Ranchi, Bangalore, Mumbai, Jaipur, Srinagar, B...  Starts Immediately
# 4218                                         Chandigarh  Starts Immediately
# 260                                           Hyderabad  Starts Immediately
# 728                                               Noida  Starts Immediately
# 2237  Ballari, Kalaburagi, Koppal, Mangaluru, Vijaya...  Starts Immediately
#
#                         ctc experience       posted   min_ctc   max_ctc  \
# 3804  ₹ 2,00,000 - 7,00,000       0-5   3 weeks ago  200000.0  700000.0
# 4218  ₹ 2,16,000 - 3,00,000       1-3   2 weeks ago  216000.0  300000.0
# 260   ₹ 2,00,000 - 3,00,000       1-4   3 days ago   200000.0  300000.0
# 728   ₹ 3,00,000 - 4,00,000       1-3   2 weeks ago  300000.0  400000.0
# 2237  ₹ 4,00,000 - 6,00,000       0-5    1 week ago  400000.0  600000.0
#
#       min_experience  max_experience
# 3804             0.0             5.0
# 4218             1.0             3.0
# 260              1.0             4.0
# 728              1.0             3.0
# 2237             0.0             5.0
