# %%
import numpy as np
import pandas as pd

import os
for dirname,_,filenames in os.walk('/Users/anishsoni/Desktop/Movie_Recommendation_System'):
    for filename in filenames:
        print(os.path.join(dirname,filename))
# Out:
# /Users/anishsoni/Desktop/Movie_Recommendation_System/Untitled.ipynb
# /Users/anishsoni/Desktop/Movie_Recommendation_System/u.data
# /Users/anishsoni/Desktop/Movie_Recommendation_System/.ipynb_checkpoints/Untitled-checkpoint.ipynb

# %%
column_names = ['user_id','item_id','rating','timestamp']
df = pd.read_csv('/Users/anishsoni/Desktop/Movie_Recommendation_System/u.data', sep= '\t', names = column_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movie_titles = pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/3936828/6848095/Movie_Id_Titles.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20231122%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20231122T152607Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df= pd.merge(df, movie_titles, on='item_id')

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# %%
# %matplotlib inline

# %%
df.groupby('title')['rating'].mean().sort_values(ascending = False).head()
# Out:
# title
# They Made Me a Criminal (1939)                5.0
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Saint of Fort Washington, The (1993)          5.0
# Someone Else's America (1995)                 5.0
# Star Kid (1997)                               5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending = False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390
