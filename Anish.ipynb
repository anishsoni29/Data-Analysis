# %%
#importing data from a csv file after importing pandas to the dataset

import pandas as pd
df = pd.read_csv("USA_CARS.csv")
print (df)
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
#convertind the dataset to a table set using DataFrame to perform mathematical operations
#DataFrame is a structure that print 2D data into a meaningful format (Tabular Format)
df1 = pd.DataFrame(df)
df1
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %% [markdown]
# Analysing the Data

# %%
df1.count()
# Out:
# Unnamed: 0      2499
# price           2499
# brand           2499
# model           2499
# year            2499
# title_status    2499
# mileage         2499
# color           2499
# vin             2499
# lot             2499
# state           2499
# country         2499
# condition       2499
# dtype: int64

# %%
print(df1.shape, df1.size)
# Out:
# (2499, 13) 32487

# %%
df1.brand, df1.mileage
# Out:
# (0          toyota
#  1            ford
#  2           dodge
#  3            ford
#  4       chevrolet
#            ...
#  2494       nissan
#  2495       nissan
#  2496       nissan
#  2497       nissan
#  2498       nissan
#  Name: brand, Length: 2499, dtype: object,
#  0       274117.0
#  1       190552.0
#  2        39590.0
#  3        64146.0
#  4         6654.0
#            ...
#  2494     23609.0
#  2495     34553.0
#  2496     31594.0
#  2497     32557.0
#  2498     31371.0
#  Name: mileage, Length: 2499, dtype: float64)

# %%
from pandas.core.base import value_counts
value_counts(df1.mileage > 6000)
# Out:
# True     2433
# False      66
# Name: mileage, dtype: int64

# %%
# Out:
#   File "<ipython-input-16-de9c22726835>", line 1
#     del('False')
#         ^
# SyntaxError: cannot delete literal

# %%
x = df1.groupby('brand', sort = True)['year'].count()
print(x)
# Out:
# brand
# acura                 3
# audi                  4
# bmw                  17
# buick                13
# cadillac             10
# chevrolet           297
# chrysler             18
# dodge               432
# ford               1235
# gmc                  42
# harley-davidson       1
# heartland             5
# honda                12
# hyundai              15
# infiniti             12
# jaguar                1
# jeep                 30
# kia                  13
# land                  4
# lexus                 2
# lincoln               2
# maserati              1
# mazda                 2
# mercedes-benz        10
# nissan              312
# peterbilt             4
# ram                   1
# toyota                1
# Name: year, dtype: int64

# %%
x.plot(kind = 'bar')
# Out:
# <Axes: xlabel='brand'>
